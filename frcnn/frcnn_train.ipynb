# %%
# !git clone https://github.com/skimkoh/cv_keras
# Out:
# Cloning into 'cv_keras'...
# remote: Enumerating objects: 1227, done.
# remote: Counting objects: 100% (1227/1227), done.
# remote: Compressing objects: 100% (812/812), done.
# remote: Total 1227 (delta 416), reused 1218 (delta 410), pack-reused 0
# Receiving objects: 100% (1227/1227), 25.58 MiB | 8.32 MiB/s, done.
# Resolving deltas: 100% (416/416), done.

# %%
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 151.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
pip install keras==2.0.3
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
# Requirement already satisfied: keras==2.0.3 in /usr/local/lib/python3.6/dist-packages (2.0.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (3.13)
# Requirement already satisfied: theano in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (1.0.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from theano->keras==2.0.3) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from theano->keras==2.0.3) (1.18.2)

# %%
pip install tensorflow==1.15
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 41kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.18.2)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 36.7MB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.27.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.9.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 49.1MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.2.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (46.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=0970d2cf40ea6e8103fd5edec6b2e6cd7fc2195dd32900d5513eb4f2eed26729
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# Installing collected packages: tensorboard, gast, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorflow 2.2.0rc2
#     Uninstalling tensorflow-2.2.0rc2:
#       Successfully uninstalled tensorflow-2.2.0rc2
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %%
import tensorflow as tf
import keras
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
# DO NOT TOUCH 
# !python train_frcnn.py -o simple -p /cv_keras/train2.txt --num_epochs 200
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'apple': 257,
#  'banana': 169,
#  'bg': 0,
#  'bread': 53,
#  'bun': 72,
#  'doughnut': 168,
#  'egg': 83,
#  'fired_dough_twist': 99,
#  'grape': 46,
#  'lemon': 148,
#  'litchi': 62,
#  'mango': 200,
#  'mooncake': 107,
#  'orange': 225,
#  'peach': 101,
#  'pear': 146,
#  'plum': 141,
#  'qiwi': 110,
#  'sachima': 120,
#  'tomato': 161}
# Num classes (including bg) = 20
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 1999
# Num val samples 403
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3153: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /content/keras-frcnn/keras_frcnn/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3045: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1064: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# loading weights from resnet50_weights_tf_dim_ordering_tf_kernels.h5
# Could not load pretrained model weights. Weights can be found in the keras application folder 		https://github.com/fchollet/keras/tree/master/keras/applications
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:675: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2642: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1046: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Starting training
# Epoch 1/200
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:768: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:521: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:764: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:141: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:151: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-21 04:17:45.152617: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-03-21 04:17:45.157471: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000125000 Hz
# 2020-03-21 04:17:45.157676: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31aef40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-21 04:17:45.157708: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-21 04:17:45.159717: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-21 04:17:45.296410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 04:17:45.297049: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31af100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-21 04:17:45.297084: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-03-21 04:17:45.297253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 04:17:45.297771: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-03-21 04:17:45.298071: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-21 04:17:45.299520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-21 04:17:45.301011: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-21 04:17:45.301362: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-21 04:17:45.302781: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-21 04:17:45.303481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-21 04:17:45.306327: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-21 04:17:45.306435: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 04:17:45.307143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 04:17:45.307656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-21 04:17:45.307727: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-21 04:17:45.308908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-21 04:17:45.308934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-21 04:17:45.308944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-21 04:17:45.309052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 04:17:45.309632: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 04:17:45.310153: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-03-21 04:17:45.310206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:300: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:308: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2020-03-21 04:17:49.197311: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-21 04:17:50.923421: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 300/300 [==============================] - 96s - rpn_cls: 1.0762 - rpn_regr: 0.1157 - detector_cls: 0.8166 - detector_regr: 0.4792
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.306666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8623958333333334
# Loss RPN classifier: 1.0761941751648434
# Loss RPN regression: 0.11571204731396088
# Loss Detector classifier: 0.8166361547758182
# Loss Detector regression: 0.4792365867147843
# Elapsed time: 96.45885920524597
# Total loss decreased from inf to 2.487778963969407, saving weights
# Epoch 2/200
# Average number of overlapping bounding boxes from RPN = 4.306666666666667 for 300 previous iterations
# 300/300 [==============================] - 79s - rpn_cls: 0.4519 - rpn_regr: 0.1400 - detector_cls: 0.7945 - detector_regr: 0.4171
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.976666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8441666666666666
# Loss RPN classifier: 0.4518737144255526
# Loss RPN regression: 0.13995038393884898
# Loss Detector classifier: 0.7944610681757331
# Loss Detector regression: 0.4171342692524195
# Elapsed time: 101.19513773918152
# Total loss decreased from 2.487778963969407 to 1.803419435792554, saving weights
# Epoch 3/200
# Average number of overlapping bounding boxes from RPN = 4.976666666666667 for 300 previous iterations
# 300/300 [==============================] - 78s - rpn_cls: 0.3803 - rpn_regr: 0.1266 - detector_cls: 0.8651 - detector_regr: 0.4099
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 6.24
# Classifier accuracy for bounding boxes from RPN: 0.808125
# Loss RPN classifier: 0.38028921097361795
# Loss RPN regression: 0.12659057907992974
# Loss Detector classifier: 0.8650506206601858
# Loss Detector regression: 0.4099079323311647
# Elapsed time: 79.37239408493042
# Total loss decreased from 1.803419435792554 to 1.7818383430448983, saving weights
# Epoch 4/200
# Average number of overlapping bounding boxes from RPN = 6.24 for 300 previous iterations
# 300/300 [==============================] - 79s - rpn_cls: 0.3394 - rpn_regr: 0.1164 - detector_cls: 0.7475 - detector_regr: 0.4038
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.826666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8202083333333333
# Loss RPN classifier: 0.33938207472229504
# Loss RPN regression: 0.11642601810240497
# Loss Detector classifier: 0.7474890794542929
# Loss Detector regression: 0.40384924923380217
# Elapsed time: 79.87034893035889
# Total loss decreased from 1.7818383430448983 to 1.607146421512795, saving weights
# Epoch 5/200
# Average number of overlapping bounding boxes from RPN = 5.826666666666667 for 300 previous iterations
# 300/300 [==============================] - 79s - rpn_cls: 0.2764 - rpn_regr: 0.1156 - detector_cls: 0.7541 - detector_regr: 0.4083
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 6.25
# Classifier accuracy for bounding boxes from RPN: 0.8073958333333333
# Loss RPN classifier: 0.2764315601402389
# Loss RPN regression: 0.11558483890102556
# Loss Detector classifier: 0.7541216732313235
# Loss Detector regression: 0.4082831546664238
# Elapsed time: 79.72792267799377
# Total loss decreased from 1.607146421512795 to 1.5544212269390119, saving weights
# Epoch 6/200
# Average number of overlapping bounding boxes from RPN = 6.25 for 300 previous iterations
# 299/300 [============================>.] - ETA: 0s - rpn_cls: 0.2432 - rpn_regr: 0.1094 - detector_cls: 0.8029 - detector_regr: 0.3730Average number of overlapping bounding boxes from RPN = 7.65 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.2462 - rpn_regr: 0.1091 - detector_cls: 0.8046 - detector_regr: 0.3734
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.6544850498338874
# Classifier accuracy for bounding boxes from RPN: 0.7765625
# Loss RPN classifier: 0.24618096276302823
# Loss RPN regression: 0.10912988413125277
# Loss Detector classifier: 0.8046253794617951
# Loss Detector regression: 0.3734212010850509
# Elapsed time: 78.2588369846344
# Total loss decreased from 1.5544212269390119 to 1.533357427441127, saving weights
# Epoch 7/200
# 299/300 [============================>.] - ETA: 0s - rpn_cls: 0.1992 - rpn_regr: 0.1039 - detector_cls: 0.7350 - detector_regr: 0.3654Average number of overlapping bounding boxes from RPN = 7.19 for 300 previous iterations
# 300/300 [==============================] - 78s - rpn_cls: 0.1988 - rpn_regr: 0.1036 - detector_cls: 0.7358 - detector_regr: 0.3657
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.203333333333333
# Classifier accuracy for bounding boxes from RPN: 0.7904166666666667
# Loss RPN classifier: 0.19878199724099735
# Loss RPN regression: 0.10360653541516512
# Loss Detector classifier: 0.7358191025753816
# Loss Detector regression: 0.36572846194108327
# Elapsed time: 79.19531440734863
# Total loss decreased from 1.533357427441127 to 1.4039360971726274, saving weights
# Epoch 8/200
# 299/300 [============================>.] - ETA: 0s - rpn_cls: 0.1784 - rpn_regr: 0.1031 - detector_cls: 0.6623 - detector_regr: 0.3443Average number of overlapping bounding boxes from RPN = 7.286666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.1778 - rpn_regr: 0.1030 - detector_cls: 0.6612 - detector_regr: 0.3440
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.256666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8046875
# Loss RPN classifier: 0.1778219821513388
# Loss RPN regression: 0.10296204253177468
# Loss Detector classifier: 0.6611632996114591
# Loss Detector regression: 0.3440093828737736
# Elapsed time: 77.22729969024658
# Total loss decreased from 1.4039360971726274 to 1.2859567071683462, saving weights
# Epoch 9/200
# 299/300 [============================>.] - ETA: 0s - rpn_cls: 0.1551 - rpn_regr: 0.0993 - detector_cls: 0.6892 - detector_regr: 0.3362Average number of overlapping bounding boxes from RPN = 7.913333333333333 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.1546 - rpn_regr: 0.0995 - detector_cls: 0.6876 - detector_regr: 0.3360
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.906666666666666
# Classifier accuracy for bounding boxes from RPN: 0.7892708333333334
# Loss RPN classifier: 0.1545865566646656
# Loss RPN regression: 0.09950967274431605
# Loss Detector classifier: 0.6876005160901696
# Loss Detector regression: 0.33602272073427836
# Elapsed time: 77.96398425102234
# Total loss decreased from 1.2859567071683462 to 1.2777194662334295, saving weights
# Epoch 10/200
# 299/300 [============================>.] - ETA: 0s - rpn_cls: 0.2019 - rpn_regr: 0.0954 - detector_cls: 0.6122 - detector_regr: 0.3155Average number of overlapping bounding boxes from RPN = 7.72 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.2013 - rpn_regr: 0.0953 - detector_cls: 0.6117 - detector_regr: 0.3156
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.743333333333333
# Classifier accuracy for bounding boxes from RPN: 0.8082291666666667
# Loss RPN classifier: 0.2012564418211332
# Loss RPN regression: 0.09527130664869522
# Loss Detector classifier: 0.6117253072435657
# Loss Detector regression: 0.3155700757354498
# Elapsed time: 77.39097142219543
# Total loss decreased from 1.2777194662334295 to 1.223823131448844, saving weights
# Epoch 11/200
# 299/300 [============================>.] - ETA: 0s - rpn_cls: 0.1409 - rpn_regr: 0.1052 - detector_cls: 0.6099 - detector_regr: 0.2999Average number of overlapping bounding boxes from RPN = 7.873333333333333 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.1404 - rpn_regr: 0.1054 - detector_cls: 0.6099 - detector_regr: 0.3001
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.87
# Classifier accuracy for bounding boxes from RPN: 0.8057291666666667
# Loss RPN classifier: 0.14040769023670388
# Loss RPN regression: 0.10542143838169674
# Loss Detector classifier: 0.6099043886860211
# Loss Detector regression: 0.30009600418309373
# Elapsed time: 77.79426050186157
# Total loss decreased from 1.223823131448844 to 1.1558295214875156, saving weights
# Epoch 12/200
# 297/300 [============================>.] - ETA: 0s - rpn_cls: 0.1952 - rpn_regr: 0.0997 - detector_cls: 0.6289 - detector_regr: 0.2932Average number of overlapping bounding boxes from RPN = 8.243333333333334 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.1948 - rpn_regr: 0.0990 - detector_cls: 0.6292 - detector_regr: 0.2939
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.274834437086092
# Classifier accuracy for bounding boxes from RPN: 0.7984375
# Loss RPN classifier: 0.19477021530129301
# Loss RPN regression: 0.09896974192932248
# Loss Detector classifier: 0.6291888178139925
# Loss Detector regression: 0.2938929401586453
# Elapsed time: 77.97410655021667
# Epoch 13/200
# 297/300 [============================>.] - ETA: 0s - rpn_cls: 0.1653 - rpn_regr: 0.0933 - detector_cls: 0.6200 - detector_regr: 0.2863Average number of overlapping bounding boxes from RPN = 8.316666666666666 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.1646 - rpn_regr: 0.0927 - detector_cls: 0.6194 - detector_regr: 0.2863
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.29
# Classifier accuracy for bounding boxes from RPN: 0.8045833333333333
# Loss RPN classifier: 0.16455857693369352
# Loss RPN regression: 0.09270496030842575
# Loss Detector classifier: 0.6194074030034245
# Loss Detector regression: 0.2862615146115422
# Elapsed time: 77.26555824279785
# Epoch 14/200
# 297/300 [============================>.] - ETA: 0s - rpn_cls: 0.1065 - rpn_regr: 0.0832 - detector_cls: 0.5306 - detector_regr: 0.2833Average number of overlapping bounding boxes from RPN = 7.863333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.1056 - rpn_regr: 0.0831 - detector_cls: 0.5311 - detector_regr: 0.2833
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.886666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8296875
# Loss RPN classifier: 0.10561964695491345
# Loss RPN regression: 0.08312895528196047
# Loss Detector classifier: 0.531071397215128
# Loss Detector regression: 0.28334518844882645
# Elapsed time: 76.60050964355469
# Total loss decreased from 1.1558295214875156 to 1.0031651879008283, saving weights
# Epoch 15/200
# 297/300 [============================>.] - ETA: 0s - rpn_cls: 0.1059 - rpn_regr: 0.0884 - detector_cls: 0.5360 - detector_regr: 0.2627Average number of overlapping bounding boxes from RPN = 8.583333333333334 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.1050 - rpn_regr: 0.0889 - detector_cls: 0.5372 - detector_regr: 0.2629
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.586666666666666
# Classifier accuracy for bounding boxes from RPN: 0.8151041666666666
# Loss RPN classifier: 0.10502534577203733
# Loss RPN regression: 0.08887173512737112
# Loss Detector classifier: 0.5371754806178312
# Loss Detector regression: 0.26286340701083344
# Elapsed time: 76.9171850681305
# Total loss decreased from 1.0031651879008283 to 0.993935968528073, saving weights
# Epoch 16/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.1153 - rpn_regr: 0.0810 - detector_cls: 0.5158 - detector_regr: 0.2385Average number of overlapping bounding boxes from RPN = 8.69 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.1163 - rpn_regr: 0.0802 - detector_cls: 0.5151 - detector_regr: 0.2389
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.654485049833887
# Classifier accuracy for bounding boxes from RPN: 0.823125
# Loss RPN classifier: 0.11631897305332396
# Loss RPN regression: 0.0801845373158964
# Loss Detector classifier: 0.5151338109746575
# Loss Detector regression: 0.238865434837838
# Elapsed time: 77.07980298995972
# Total loss decreased from 0.993935968528073 to 0.9505027561817159, saving weights
# Epoch 17/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0970 - rpn_regr: 0.0792 - detector_cls: 0.5117 - detector_regr: 0.2460Average number of overlapping bounding boxes from RPN = 8.45 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0958 - rpn_regr: 0.0784 - detector_cls: 0.5136 - detector_regr: 0.2464
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.46
# Classifier accuracy for bounding boxes from RPN: 0.8239583333333333
# Loss RPN classifier: 0.09582287914108671
# Loss RPN regression: 0.07843169595774574
# Loss Detector classifier: 0.5136390411419173
# Loss Detector regression: 0.24637163316210112
# Elapsed time: 77.11757802963257
# Total loss decreased from 0.9505027561817159 to 0.9342652494028508, saving weights
# Epoch 18/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0900 - rpn_regr: 0.0740 - detector_cls: 0.4905 - detector_regr: 0.2449Average number of overlapping bounding boxes from RPN = 8.726666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0894 - rpn_regr: 0.0746 - detector_cls: 0.4903 - detector_regr: 0.2455
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.696666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8269791666666667
# Loss RPN classifier: 0.0894049050168868
# Loss RPN regression: 0.07459223353808435
# Loss Detector classifier: 0.4903384018751482
# Loss Detector regression: 0.24554427824914454
# Elapsed time: 77.09609293937683
# Total loss decreased from 0.9342652494028508 to 0.899879818679264, saving weights
# Epoch 19/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0803 - rpn_regr: 0.0827 - detector_cls: 0.5168 - detector_regr: 0.2410Average number of overlapping bounding boxes from RPN = 8.873333333333333 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.0793 - rpn_regr: 0.0826 - detector_cls: 0.5150 - detector_regr: 0.2398
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.876666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8223958333333333
# Loss RPN classifier: 0.07930048591947676
# Loss RPN regression: 0.08256465289508924
# Loss Detector classifier: 0.5150324737932533
# Loss Detector regression: 0.23978917699307203
# Elapsed time: 77.57966947555542
# Epoch 20/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0724 - rpn_regr: 0.0826 - detector_cls: 0.4813 - detector_regr: 0.2214Average number of overlapping bounding boxes from RPN = 9.403333333333334 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0716 - rpn_regr: 0.0822 - detector_cls: 0.4848 - detector_regr: 0.2219
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.493333333333334
# Classifier accuracy for bounding boxes from RPN: 0.8330208333333333
# Loss RPN classifier: 0.07164360806267457
# Loss RPN regression: 0.08220218777268504
# Loss Detector classifier: 0.48480539992762106
# Loss Detector regression: 0.22190759016821782
# Elapsed time: 76.86436057090759
# Total loss decreased from 0.899879818679264 to 0.8605587859311985, saving weights
# Epoch 21/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0662 - rpn_regr: 0.0697 - detector_cls: 0.4545 - detector_regr: 0.2163Average number of overlapping bounding boxes from RPN = 9.02 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0654 - rpn_regr: 0.0695 - detector_cls: 0.4550 - detector_regr: 0.2160
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.943333333333333
# Classifier accuracy for bounding boxes from RPN: 0.8402083333333333
# Loss RPN classifier: 0.06541403059548467
# Loss RPN regression: 0.06945193478468961
# Loss Detector classifier: 0.45504055578960106
# Loss Detector regression: 0.21596394353856643
# Elapsed time: 77.1755735874176
# Total loss decreased from 0.8605587859311985 to 0.8058704647083418, saving weights
# Epoch 22/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0828 - rpn_regr: 0.0736 - detector_cls: 0.4223 - detector_regr: 0.2040Average number of overlapping bounding boxes from RPN = 9.206666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0818 - rpn_regr: 0.0728 - detector_cls: 0.4261 - detector_regr: 0.2043
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.253333333333334
# Classifier accuracy for bounding boxes from RPN: 0.8535416666666666
# Loss RPN classifier: 0.08182443246632877
# Loss RPN regression: 0.07283959347880833
# Loss Detector classifier: 0.42613763409123445
# Loss Detector regression: 0.20425418189416328
# Elapsed time: 76.73502445220947
# Total loss decreased from 0.8058704647083418 to 0.7850558419305349, saving weights
# Epoch 23/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0680 - rpn_regr: 0.0605 - detector_cls: 0.4315 - detector_regr: 0.2075Average number of overlapping bounding boxes from RPN = 9.863333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0671 - rpn_regr: 0.0610 - detector_cls: 0.4326 - detector_regr: 0.2083
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.866666666666667
# Classifier accuracy for bounding boxes from RPN: 0.844375
# Loss RPN classifier: 0.06713902381546631
# Loss RPN regression: 0.06097053340092922
# Loss Detector classifier: 0.4326192703222235
# Loss Detector regression: 0.20834740042686462
# Elapsed time: 77.30406546592712
# Total loss decreased from 0.7850558419305349 to 0.7690762279654837, saving weights
# Epoch 24/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0880 - rpn_regr: 0.0625 - detector_cls: 0.4216 - detector_regr: 0.2040Average number of overlapping bounding boxes from RPN = 9.633333333333333 for 300 previous iterations
# 300/300 [==============================] - 78s - rpn_cls: 0.0870 - rpn_regr: 0.0632 - detector_cls: 0.4193 - detector_regr: 0.2021
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.543333333333333
# Classifier accuracy for bounding boxes from RPN: 0.8576041666666666
# Loss RPN classifier: 0.08704179693785752
# Loss RPN regression: 0.06323633052777344
# Loss Detector classifier: 0.4193278847696881
# Loss Detector regression: 0.20210490542153517
# Elapsed time: 78.53803300857544
# Epoch 25/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0991 - rpn_regr: 0.0600 - detector_cls: 0.4210 - detector_regr: 0.1997Average number of overlapping bounding boxes from RPN = 9.426666666666666 for 300 previous iterations
# 300/300 [==============================] - 78s - rpn_cls: 0.0982 - rpn_regr: 0.0595 - detector_cls: 0.4202 - detector_regr: 0.1996
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.516666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8490625
# Loss RPN classifier: 0.09823308997381133
# Loss RPN regression: 0.05949408325715922
# Loss Detector classifier: 0.4201871513451139
# Loss Detector regression: 0.1995617762953043
# Elapsed time: 78.0283944606781
# Epoch 26/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0718 - rpn_regr: 0.0713 - detector_cls: 0.4114 - detector_regr: 0.1985Average number of overlapping bounding boxes from RPN = 9.013333333333334 for 300 previous iterations
# 300/300 [==============================] - 78s - rpn_cls: 0.0710 - rpn_regr: 0.0707 - detector_cls: 0.4119 - detector_regr: 0.1991
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.983333333333333
# Classifier accuracy for bounding boxes from RPN: 0.855
# Loss RPN classifier: 0.07100598400719368
# Loss RPN regression: 0.07070270406509128
# Loss Detector classifier: 0.41185332572036715
# Loss Detector regression: 0.1991342416529854
# Elapsed time: 78.20102548599243
# Total loss decreased from 0.7690762279654837 to 0.7526962554456376, saving weights
# Epoch 27/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0751 - rpn_regr: 0.0586 - detector_cls: 0.4424 - detector_regr: 0.2012Average number of overlapping bounding boxes from RPN = 9.943333333333333 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.0743 - rpn_regr: 0.0583 - detector_cls: 0.4402 - detector_regr: 0.2003
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.956666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8384375
# Loss RPN classifier: 0.07426132615250265
# Loss RPN regression: 0.058307387083186765
# Loss Detector classifier: 0.44018730357289315
# Loss Detector regression: 0.20027050275355576
# Elapsed time: 78.1247124671936
# Epoch 28/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0317 - rpn_regr: 0.0474 - detector_cls: 0.3994 - detector_regr: 0.1807Average number of overlapping bounding boxes from RPN = 9.29 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0314 - rpn_regr: 0.0475 - detector_cls: 0.3994 - detector_regr: 0.1805
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.303333333333333
# Classifier accuracy for bounding boxes from RPN: 0.8540625
# Loss RPN classifier: 0.0313576036862023
# Loss RPN regression: 0.0475339520618824
# Loss Detector classifier: 0.39943886431322123
# Loss Detector regression: 0.18054282978797953
# Elapsed time: 76.8526656627655
# Total loss decreased from 0.7526962554456376 to 0.6588732498492855, saving weights
# Epoch 29/200
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 0.0419 - rpn_regr: 0.0555 - detector_cls: 0.3627 - detector_regr: 0.1544Average number of overlapping bounding boxes from RPN = 9.553333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0418 - rpn_regr: 0.0556 - detector_cls: 0.3608 - detector_regr: 0.1548
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.506666666666666
# Classifier accuracy for bounding boxes from RPN: 0.8730208333333334
# Loss RPN classifier: 0.0417826818199822
# Loss RPN regression: 0.05555815974541474
# Loss Detector classifier: 0.3608447174138079
# Loss Detector regression: 0.15476071810349823
# Elapsed time: 77.00420188903809
# Total loss decreased from 0.6588732498492855 to 0.6129462770827031, saving weights
# Epoch 30/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0433 - rpn_regr: 0.0543 - detector_cls: 0.3864 - detector_regr: 0.1716Average number of overlapping bounding boxes from RPN = 8.98 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0425 - rpn_regr: 0.0544 - detector_cls: 0.3894 - detector_regr: 0.1708
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.0
# Classifier accuracy for bounding boxes from RPN: 0.85875
# Loss RPN classifier: 0.042549934472218116
# Loss RPN regression: 0.05444885859576364
# Loss Detector classifier: 0.38942279526386603
# Loss Detector regression: 0.1708294490352273
# Elapsed time: 77.1462652683258
# Epoch 31/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0566 - rpn_regr: 0.0446 - detector_cls: 0.3510 - detector_regr: 0.1632Average number of overlapping bounding boxes from RPN = 9.78 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0569 - rpn_regr: 0.0446 - detector_cls: 0.3519 - detector_regr: 0.1634
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.783333333333333
# Classifier accuracy for bounding boxes from RPN: 0.8691666666666666
# Loss RPN classifier: 0.05690738250709844
# Loss RPN regression: 0.04464853461346744
# Loss Detector classifier: 0.3519290789185713
# Loss Detector regression: 0.16335688592245182
# Elapsed time: 76.79532408714294
# Epoch 32/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0421 - rpn_regr: 0.0603 - detector_cls: 0.3672 - detector_regr: 0.1712Average number of overlapping bounding boxes from RPN = 9.32 for 300 previous iterations
# 300/300 [==============================] - 77s - rpn_cls: 0.0426 - rpn_regr: 0.0608 - detector_cls: 0.3663 - detector_regr: 0.1710
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.313333333333333
# Classifier accuracy for bounding boxes from RPN: 0.86375
# Loss RPN classifier: 0.0425530529079604
# Loss RPN regression: 0.060838739767010944
# Loss Detector classifier: 0.3663461504628261
# Loss Detector regression: 0.17096311728159586
# Elapsed time: 77.06503391265869
# Epoch 33/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0638 - rpn_regr: 0.0563 - detector_cls: 0.3666 - detector_regr: 0.1673Average number of overlapping bounding boxes from RPN = 10.15 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0628 - rpn_regr: 0.0558 - detector_cls: 0.3631 - detector_regr: 0.1675
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.12
# Classifier accuracy for bounding boxes from RPN: 0.8714583333333333
# Loss RPN classifier: 0.06278576286199503
# Loss RPN regression: 0.055806896443245935
# Loss Detector classifier: 0.3631191906891763
# Loss Detector regression: 0.16748134550948937
# Elapsed time: 76.6439471244812
# Epoch 34/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0656 - rpn_regr: 0.0512 - detector_cls: 0.3435 - detector_regr: 0.1567Average number of overlapping bounding boxes from RPN = 9.186666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0648 - rpn_regr: 0.0507 - detector_cls: 0.3409 - detector_regr: 0.1561
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.21
# Classifier accuracy for bounding boxes from RPN: 0.8705208333333333
# Loss RPN classifier: 0.06481299407729312
# Loss RPN regression: 0.050725182544750475
# Loss Detector classifier: 0.3409115109903117
# Loss Detector regression: 0.15611495787277818
# Elapsed time: 76.88017511367798
# Total loss decreased from 0.6129462770827031 to 0.6125646454851335, saving weights
# Epoch 35/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0554 - rpn_regr: 0.0437 - detector_cls: 0.3499 - detector_regr: 0.1642Average number of overlapping bounding boxes from RPN = 9.453333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0546 - rpn_regr: 0.0437 - detector_cls: 0.3515 - detector_regr: 0.1633
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.43
# Classifier accuracy for bounding boxes from RPN: 0.8690625
# Loss RPN classifier: 0.05457308994341264
# Loss RPN regression: 0.043681517510752506
# Loss Detector classifier: 0.3515483947719137
# Loss Detector regression: 0.16333594043428698
# Elapsed time: 77.21599078178406
# Epoch 36/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0330 - rpn_regr: 0.0490 - detector_cls: 0.3281 - detector_regr: 0.1499Average number of overlapping bounding boxes from RPN = 9.193333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0326 - rpn_regr: 0.0483 - detector_cls: 0.3283 - detector_regr: 0.1503
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.206666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8766666666666667
# Loss RPN classifier: 0.03257641942821228
# Loss RPN regression: 0.048338066633829536
# Loss Detector classifier: 0.32833931713850084
# Loss Detector regression: 0.15025546247760455
# Elapsed time: 76.88318514823914
# Total loss decreased from 0.6125646454851335 to 0.5595092656781472, saving weights
# Epoch 37/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0151 - rpn_regr: 0.0409 - detector_cls: 0.3331 - detector_regr: 0.1452Average number of overlapping bounding boxes from RPN = 9.38 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0156 - rpn_regr: 0.0409 - detector_cls: 0.3318 - detector_regr: 0.1459
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.396666666666667
# Classifier accuracy for bounding boxes from RPN: 0.879375
# Loss RPN classifier: 0.015614698028200587
# Loss RPN regression: 0.04092325822915882
# Loss Detector classifier: 0.3317503746040165
# Loss Detector regression: 0.1459306646619613
# Elapsed time: 77.20516633987427
# Total loss decreased from 0.5595092656781472 to 0.5342189955233372, saving weights
# Epoch 38/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0220 - rpn_regr: 0.0478 - detector_cls: 0.3169 - detector_regr: 0.1403Average number of overlapping bounding boxes from RPN = 8.823333333333334 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0216 - rpn_regr: 0.0473 - detector_cls: 0.3154 - detector_regr: 0.1406
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.826666666666666
# Classifier accuracy for bounding boxes from RPN: 0.8838541666666667
# Loss RPN classifier: 0.02161803305063967
# Loss RPN regression: 0.04734890679906433
# Loss Detector classifier: 0.3153909693285823
# Loss Detector regression: 0.14060555255040527
# Elapsed time: 76.99369740486145
# Total loss decreased from 0.5342189955233372 to 0.5249634617286916, saving weights
# Epoch 39/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0257 - rpn_regr: 0.0455 - detector_cls: 0.3170 - detector_regr: 0.1384Average number of overlapping bounding boxes from RPN = 9.136666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0253 - rpn_regr: 0.0453 - detector_cls: 0.3161 - detector_regr: 0.1384
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.116666666666667
# Classifier accuracy for bounding boxes from RPN: 0.8729166666666667
# Loss RPN classifier: 0.025325604142915382
# Loss RPN regression: 0.04530356675832688
# Loss Detector classifier: 0.31611072149438163
# Loss Detector regression: 0.13841750387102367
# Elapsed time: 77.12361478805542
# Epoch 40/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0537 - rpn_regr: 0.0469 - detector_cls: 0.2964 - detector_regr: 0.1420Average number of overlapping bounding boxes from RPN = 9.876666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0530 - rpn_regr: 0.0469 - detector_cls: 0.2983 - detector_regr: 0.1421
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.953333333333333
# Classifier accuracy for bounding boxes from RPN: 0.8902083333333334
# Loss RPN classifier: 0.05298012767234262
# Loss RPN regression: 0.04686530090674448
# Loss Detector classifier: 0.29828814990818503
# Loss Detector regression: 0.1420989164089163
# Elapsed time: 76.8907687664032
# Epoch 41/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0382 - rpn_regr: 0.0405 - detector_cls: 0.2713 - detector_regr: 0.1291Average number of overlapping bounding boxes from RPN = 9.276666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0376 - rpn_regr: 0.0401 - detector_cls: 0.2704 - detector_regr: 0.1283
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.176666666666666
# Classifier accuracy for bounding boxes from RPN: 0.9017708333333333
# Loss RPN classifier: 0.0375643211743219
# Loss RPN regression: 0.04007120645566223
# Loss Detector classifier: 0.2704230476496741
# Loss Detector regression: 0.12831792575617632
# Elapsed time: 76.56174349784851
# Total loss decreased from 0.5249634617286916 to 0.4763765010358345, saving weights
# Epoch 42/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0376 - rpn_regr: 0.0468 - detector_cls: 0.2640 - detector_regr: 0.1251Average number of overlapping bounding boxes from RPN = 8.453333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0371 - rpn_regr: 0.0463 - detector_cls: 0.2632 - detector_regr: 0.1251
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.48
# Classifier accuracy for bounding boxes from RPN: 0.9032291666666666
# Loss RPN classifier: 0.03708026943565287
# Loss RPN regression: 0.04627399647249452
# Loss Detector classifier: 0.26315711125111646
# Loss Detector regression: 0.1250681951486816
# Elapsed time: 77.13438010215759
# Total loss decreased from 0.4763765010358345 to 0.47157957230794545, saving weights
# Epoch 43/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0520 - rpn_regr: 0.0394 - detector_cls: 0.2944 - detector_regr: 0.1435Average number of overlapping bounding boxes from RPN = 8.65 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0512 - rpn_regr: 0.0392 - detector_cls: 0.2938 - detector_regr: 0.1432
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.646666666666667
# Classifier accuracy for bounding boxes from RPN: 0.88875
# Loss RPN classifier: 0.05123192173492567
# Loss RPN regression: 0.03923671746180238
# Loss Detector classifier: 0.29375604594747223
# Loss Detector regression: 0.14315901935410996
# Elapsed time: 77.12490725517273
# Epoch 44/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0402 - rpn_regr: 0.0336 - detector_cls: 0.2952 - detector_regr: 0.1297Average number of overlapping bounding boxes from RPN = 9.806666666666667 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0404 - rpn_regr: 0.0336 - detector_cls: 0.2934 - detector_regr: 0.1300
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.803333333333333
# Classifier accuracy for bounding boxes from RPN: 0.8882291666666666
# Loss RPN classifier: 0.04042428776923063
# Loss RPN regression: 0.0335872028011363
# Loss Detector classifier: 0.2933944159497817
# Loss Detector regression: 0.1299853000168999
# Elapsed time: 76.79649448394775
# Epoch 45/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0373 - rpn_regr: 0.0495 - detector_cls: 0.3097 - detector_regr: 0.1411Average number of overlapping bounding boxes from RPN = 8.98 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0369 - rpn_regr: 0.0489 - detector_cls: 0.3091 - detector_regr: 0.1413
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.993333333333334
# Classifier accuracy for bounding boxes from RPN: 0.8880208333333334
# Loss RPN classifier: 0.03685918581157386
# Loss RPN regression: 0.04889885148499161
# Loss Detector classifier: 0.3090527249624332
# Loss Detector regression: 0.1413429794833064
# Elapsed time: 76.93136215209961
# Epoch 46/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0205 - rpn_regr: 0.0357 - detector_cls: 0.3177 - detector_regr: 0.1286Average number of overlapping bounding boxes from RPN = 9.69 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0205 - rpn_regr: 0.0358 - detector_cls: 0.3220 - detector_regr: 0.1283
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.75
# Classifier accuracy for bounding boxes from RPN: 0.8771875
# Loss RPN classifier: 0.020460222387418483
# Loss RPN regression: 0.035832690994053944
# Loss Detector classifier: 0.32201368211768566
# Loss Detector regression: 0.1282643748447299
# Elapsed time: 76.13245701789856
# Epoch 47/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0280 - rpn_regr: 0.0426 - detector_cls: 0.2800 - detector_regr: 0.1278Average number of overlapping bounding boxes from RPN = 9.103333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0280 - rpn_regr: 0.0423 - detector_cls: 0.2782 - detector_regr: 0.1270
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.06
# Classifier accuracy for bounding boxes from RPN: 0.8935416666666667
# Loss RPN classifier: 0.027973949196779913
# Loss RPN regression: 0.04228762405575253
# Loss Detector classifier: 0.27818827209994196
# Loss Detector regression: 0.1269545190812399
# Elapsed time: 76.30640482902527
# Epoch 48/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0072 - rpn_regr: 0.0250 - detector_cls: 0.2638 - detector_regr: 0.1173Average number of overlapping bounding boxes from RPN = 9.863333333333333 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0072 - rpn_regr: 0.0249 - detector_cls: 0.2634 - detector_regr: 0.1168
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.866666666666667
# Classifier accuracy for bounding boxes from RPN: 0.9002083333333334
# Loss RPN classifier: 0.007156245386571409
# Loss RPN regression: 0.02493543133197818
# Loss Detector classifier: 0.2633650554406146
# Loss Detector regression: 0.1168069503021737
# Elapsed time: 76.81275534629822
# Total loss decreased from 0.47157957230794545 to 0.4122636824613379, saving weights
# Epoch 49/200
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 0.0229 - rpn_regr: 0.0329 - detector_cls: 0.2485 - detector_regr: 0.1125Average number of overlapping bounding boxes from RPN = 8.846666666666666 for 300 previous iterations
# 300/300 [==============================] - 76s - rpn_cls: 0.0225 - rpn_regr: 0.0328 - detector_cls: 0.2479 - detector_regr: 0.1130
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.833333333333334
# Classifier accuracy for bounding boxes from RPN: 0.90125
# Loss RPN classifier: 0.022544505157113547
# Loss RPN regression: 0.03277755438893413
# Loss Detector classifier: 0.24794620639348675
# Loss Detector regression: 0.11300743604078889
# Elapsed time: 77.35011553764343
# Epoch 50/200
# ...
# Classifier accuracy for bounding boxes from RPN: 0.9585416666666666
# Loss RPN classifier: 0.004860638539518831
# Loss RPN regression: 0.009209243955847341
# Loss Detector classifier: 0.10799865584859314
# Loss Detector regression: 0.04087618203212817
# Elapsed time: 74.10445547103882
# Epoch 180/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0015 - rpn_regr: 0.0101 - detector_cls: 0.1182 - detector_regr: 0.0441Average number of overlapping bounding boxes from RPN = 9.016666666666667 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0015 - rpn_regr: 0.0100 - detector_cls: 0.1173 - detector_regr: 0.0442
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.95
# Classifier accuracy for bounding boxes from RPN: 0.9520833333333333
# Loss RPN classifier: 0.001513678467532363
# Loss RPN regression: 0.01003083424215826
# Loss Detector classifier: 0.1172575671869951
# Loss Detector regression: 0.04423649372688184
# Elapsed time: 73.69023299217224
# Epoch 181/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 9.5969e-04 - rpn_regr: 0.0082 - detector_cls: 0.0875 - detector_regr: 0.0334Average number of overlapping bounding boxes from RPN = 8.523333333333333 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 9.4209e-04 - rpn_regr: 0.0083 - detector_cls: 0.0871 - detector_regr: 0.0335
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.49
# Classifier accuracy for bounding boxes from RPN: 0.9651041666666667
# Loss RPN classifier: 0.000942088491945204
# Loss RPN regression: 0.008327457879010278
# Loss Detector classifier: 0.08713945636486944
# Loss Detector regression: 0.03345222826348618
# Elapsed time: 73.3160228729248
# Epoch 182/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0029 - rpn_regr: 0.0091 - detector_cls: 0.1045 - detector_regr: 0.0402Average number of overlapping bounding boxes from RPN = 8.843333333333334 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0028 - rpn_regr: 0.0091 - detector_cls: 0.1041 - detector_regr: 0.0402
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.89
# Classifier accuracy for bounding boxes from RPN: 0.9566666666666667
# Loss RPN classifier: 0.002818835815736283
# Loss RPN regression: 0.009057428851956501
# Loss Detector classifier: 0.10411352035977567
# Loss Detector regression: 0.040240183301114785
# Elapsed time: 73.32522892951965
# Epoch 183/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 8.6339e-04 - rpn_regr: 0.0080 - detector_cls: 0.1016 - detector_regr: 0.0363Average number of overlapping bounding boxes from RPN = 8.083333333333334 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 8.6686e-04 - rpn_regr: 0.0080 - detector_cls: 0.1011 - detector_regr: 0.0360
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.073333333333334
# Classifier accuracy for bounding boxes from RPN: 0.9590625
# Loss RPN classifier: 0.0008668557983201689
# Loss RPN regression: 0.007993943930972212
# Loss Detector classifier: 0.10110451428467059
# Loss Detector regression: 0.03596329073033606
# Elapsed time: 73.19848823547363
# Epoch 184/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0068 - rpn_regr: 0.0089 - detector_cls: 0.0991 - detector_regr: 0.0357Average number of overlapping bounding boxes from RPN = 8.753333333333334 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0067 - rpn_regr: 0.0088 - detector_cls: 0.0991 - detector_regr: 0.0357
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.736666666666666
# Classifier accuracy for bounding boxes from RPN: 0.9592708333333333
# Loss RPN classifier: 0.006665050229511019
# Loss RPN regression: 0.008834879217514148
# Loss Detector classifier: 0.09913397014102278
# Loss Detector regression: 0.035683982723858206
# Elapsed time: 73.49460530281067
# Epoch 185/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0053 - rpn_regr: 0.0117 - detector_cls: 0.1082 - detector_regr: 0.0383Average number of overlapping bounding boxes from RPN = 8.046666666666667 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0052 - rpn_regr: 0.0116 - detector_cls: 0.1084 - detector_regr: 0.0384
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.053333333333333
# Classifier accuracy for bounding boxes from RPN: 0.9570833333333333
# Loss RPN classifier: 0.005227145954829998
# Loss RPN regression: 0.011592193688848056
# Loss Detector classifier: 0.10841882839566097
# Loss Detector regression: 0.038441393123939634
# Elapsed time: 73.20977568626404
# Epoch 186/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 9.1043e-04 - rpn_regr: 0.0096 - detector_cls: 0.0858 - detector_regr: 0.0334Average number of overlapping bounding boxes from RPN = 8.42 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 8.9249e-04 - rpn_regr: 0.0095 - detector_cls: 0.0854 - detector_regr: 0.0336
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.403333333333334
# Classifier accuracy for bounding boxes from RPN: 0.96625
# Loss RPN classifier: 0.0008924921940563024
# Loss RPN regression: 0.009527872125133096
# Loss Detector classifier: 0.08544349470253412
# Loss Detector regression: 0.03357020200074961
# Elapsed time: 73.05555295944214
# Epoch 187/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 6.0290e-04 - rpn_regr: 0.0079 - detector_cls: 0.1230 - detector_regr: 0.0356Average number of overlapping bounding boxes from RPN = 8.68 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 5.9140e-04 - rpn_regr: 0.0079 - detector_cls: 0.1219 - detector_regr: 0.0354
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.7
# Classifier accuracy for bounding boxes from RPN: 0.9530208333333333
# Loss RPN classifier: 0.0005914008800722806
# Loss RPN regression: 0.007857643639338979
# Loss Detector classifier: 0.1218756819011954
# Loss Detector regression: 0.03536273675039411
# Elapsed time: 73.81000900268555
# Epoch 188/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 4.4549e-04 - rpn_regr: 0.0065 - detector_cls: 0.0914 - detector_regr: 0.0301Average number of overlapping bounding boxes from RPN = 8.593333333333334 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 4.3753e-04 - rpn_regr: 0.0064 - detector_cls: 0.0905 - detector_regr: 0.0299
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.593333333333334
# Classifier accuracy for bounding boxes from RPN: 0.9657291666666666
# Loss RPN classifier: 0.0004375257255922331
# Loss RPN regression: 0.006394811030428779
# Loss Detector classifier: 0.09053133105888264
# Loss Detector regression: 0.029853176955754557
# Elapsed time: 73.24940943717957
# Total loss decreased from 0.12835894658762176 to 0.12721684477065823, saving weights
# Epoch 189/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0050 - rpn_regr: 0.0083 - detector_cls: 0.0961 - detector_regr: 0.0323Average number of overlapping bounding boxes from RPN = 8.443333333333333 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0049 - rpn_regr: 0.0083 - detector_cls: 0.0963 - detector_regr: 0.0325
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.483333333333333
# Classifier accuracy for bounding boxes from RPN: 0.9580208333333333
# Loss RPN classifier: 0.0049407625046029345
# Loss RPN regression: 0.008251028866179694
# Loss Detector classifier: 0.09634408552160798
# Loss Detector regression: 0.03246709676537042
# Elapsed time: 73.77563953399658
# Epoch 190/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 6.0413e-04 - rpn_regr: 0.0092 - detector_cls: 0.0907 - detector_regr: 0.0316Average number of overlapping bounding boxes from RPN = 8.776666666666667 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 5.9209e-04 - rpn_regr: 0.0091 - detector_cls: 0.0902 - detector_regr: 0.0313
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.796666666666667
# Classifier accuracy for bounding boxes from RPN: 0.9647916666666667
# Loss RPN classifier: 0.0005920882911971859
# Loss RPN regression: 0.009106822203636207
# Loss Detector classifier: 0.0901877839344282
# Loss Detector regression: 0.03134260711803411
# Elapsed time: 73.16428232192993
# Epoch 191/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0044 - rpn_regr: 0.0104 - detector_cls: 0.0901 - detector_regr: 0.0352Average number of overlapping bounding boxes from RPN = 8.616666666666667 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0043 - rpn_regr: 0.0104 - detector_cls: 0.0910 - detector_regr: 0.0351
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.586666666666666
# Classifier accuracy for bounding boxes from RPN: 0.9622916666666667
# Loss RPN classifier: 0.00432779071856776
# Loss RPN regression: 0.010378274300019258
# Loss Detector classifier: 0.09097025803484333
# Loss Detector regression: 0.03506478509788091
# Elapsed time: 73.4093165397644
# Epoch 192/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0150 - rpn_regr: 0.0104 - detector_cls: 0.0971 - detector_regr: 0.0396Average number of overlapping bounding boxes from RPN = 7.596666666666667 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0147 - rpn_regr: 0.0104 - detector_cls: 0.0971 - detector_regr: 0.0401
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.513333333333334
# Classifier accuracy for bounding boxes from RPN: 0.9636458333333333
# Loss RPN classifier: 0.01468893936023574
# Loss RPN regression: 0.010401284586890446
# Loss Detector classifier: 0.09707727782738705
# Loss Detector regression: 0.040050199782320606
# Elapsed time: 73.05783176422119
# Epoch 193/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0100 - rpn_regr: 0.0112 - detector_cls: 0.0985 - detector_regr: 0.0395Average number of overlapping bounding boxes from RPN = 8.063333333333333 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 0.0098 - rpn_regr: 0.0111 - detector_cls: 0.0986 - detector_regr: 0.0393
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.176666666666666
# Classifier accuracy for bounding boxes from RPN: 0.9588541666666667
# Loss RPN classifier: 0.009774537730937307
# Loss RPN regression: 0.011096965634011819
# Loss Detector classifier: 0.09859618054062594
# Loss Detector regression: 0.039308973331935705
# Elapsed time: 73.3296012878418
# Epoch 194/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 9.9825e-04 - rpn_regr: 0.0082 - detector_cls: 0.0923 - detector_regr: 0.0345Average number of overlapping bounding boxes from RPN = 8.07 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 9.9343e-04 - rpn_regr: 0.0083 - detector_cls: 0.0931 - detector_regr: 0.0347
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.056666666666667
# Classifier accuracy for bounding boxes from RPN: 0.96
# Loss RPN classifier: 0.0009934263742989201
# Loss RPN regression: 0.008290061162018294
# Loss Detector classifier: 0.09306888246675954
# Loss Detector regression: 0.03468074414568643
# Elapsed time: 73.52314853668213
# Epoch 195/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0245 - rpn_regr: 0.0083 - detector_cls: 0.0987 - detector_regr: 0.0330Average number of overlapping bounding boxes from RPN = 8.55 for 300 previous iterations
# 300/300 [==============================] - 74s - rpn_cls: 0.0240 - rpn_regr: 0.0083 - detector_cls: 0.0983 - detector_regr: 0.0327
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.466666666666667
# Classifier accuracy for bounding boxes from RPN: 0.95875
# Loss RPN classifier: 0.024012309067178064
# Loss RPN regression: 0.008320847644014672
# Loss Detector classifier: 0.09831702951729919
# Loss Detector regression: 0.03269123144447803
# Elapsed time: 74.11111950874329
# Epoch 196/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0056 - rpn_regr: 0.0095 - detector_cls: 0.0827 - detector_regr: 0.0321Average number of overlapping bounding boxes from RPN = 8.2 for 300 previous iterations
# 300/300 [==============================] - 74s - rpn_cls: 0.0059 - rpn_regr: 0.0095 - detector_cls: 0.0830 - detector_regr: 0.0322
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.253333333333334
# Classifier accuracy for bounding boxes from RPN: 0.9669791666666666
# Loss RPN classifier: 0.005874887820111046
# Loss RPN regression: 0.009482375395067114
# Loss Detector classifier: 0.0829866996888207
# Loss Detector regression: 0.0322377062550125
# Elapsed time: 74.26322412490845
# Epoch 197/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 1.1500e-04 - rpn_regr: 0.0076 - detector_cls: 0.0936 - detector_regr: 0.0335Average number of overlapping bounding boxes from RPN = 8.6 for 300 previous iterations
# 300/300 [==============================] - 74s - rpn_cls: 1.1403e-04 - rpn_regr: 0.0076 - detector_cls: 0.0930 - detector_regr: 0.0332
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.59
# Classifier accuracy for bounding boxes from RPN: 0.9644791666666667
# Loss RPN classifier: 0.00011403078113543093
# Loss RPN regression: 0.007567541807463082
# Loss Detector classifier: 0.0929694767560189
# Loss Detector regression: 0.03323455417683969
# Elapsed time: 74.10139966011047
# Epoch 198/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 9.6145e-04 - rpn_regr: 0.0069 - detector_cls: 0.0946 - detector_regr: 0.0339Average number of overlapping bounding boxes from RPN = 8.673333333333334 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 9.4568e-04 - rpn_regr: 0.0071 - detector_cls: 0.0952 - detector_regr: 0.0341
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.706666666666667
# Classifier accuracy for bounding boxes from RPN: 0.9628125
# Loss RPN classifier: 0.0009456808462414301
# Loss RPN regression: 0.007066109388542827
# Loss Detector classifier: 0.09524802956283263
# Loss Detector regression: 0.03412593019660562
# Elapsed time: 73.5970344543457
# Epoch 199/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 3.0249e-04 - rpn_regr: 0.0072 - detector_cls: 0.0907 - detector_regr: 0.0359Average number of overlapping bounding boxes from RPN = 8.386666666666667 for 300 previous iterations
# 300/300 [==============================] - 73s - rpn_cls: 3.0113e-04 - rpn_regr: 0.0071 - detector_cls: 0.0903 - detector_regr: 0.0361
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.31
# Classifier accuracy for bounding boxes from RPN: 0.9648958333333333
# Loss RPN classifier: 0.00030113091217039313
# Loss RPN regression: 0.0071013006888097155
# Loss Detector classifier: 0.09026259930881982
# Loss Detector regression: 0.03614023600860188
# Elapsed time: 73.34415578842163
# Epoch 200/200
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 0.0022 - rpn_regr: 0.0083 - detector_cls: 0.0882 - detector_regr: 0.0347Average number of overlapping bounding boxes from RPN = 8.4 for 300 previous iterations
# 300/300 [==============================] - 72s - rpn_cls: 0.0022 - rpn_regr: 0.0082 - detector_cls: 0.0873 - detector_regr: 0.0343
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.483333333333333
# Classifier accuracy for bounding boxes from RPN: 0.9641666666666666
# Loss RPN classifier: 0.0021874885589290233
# Loss RPN regression: 0.008224923341040268
# Loss Detector classifier: 0.08726815194376589
# Loss Detector regression: 0.03434398259889955
# Elapsed time: 72.95437669754028
# Training complete, exiting.
